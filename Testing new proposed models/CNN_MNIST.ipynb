# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers


# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)



model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

#model.summary()



batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

"""
## Evaluate the trained model
"""

score = model.evaluate(x_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/15
# 422/422 [==============================] - 8s 18ms/step - loss: 0.4308 - accuracy: 0.8789 - val_loss: 0.1657 - val_accuracy: 0.9573
# Epoch 2/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.1955 - accuracy: 0.9420 - val_loss: 0.1118 - val_accuracy: 0.9718
# Epoch 3/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.1500 - accuracy: 0.9558 - val_loss: 0.0905 - val_accuracy: 0.9772
# Epoch 4/15
# 422/422 [==============================] - 8s 18ms/step - loss: 0.1267 - accuracy: 0.9624 - val_loss: 0.0811 - val_accuracy: 0.9795
# Epoch 5/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.1117 - accuracy: 0.9663 - val_loss: 0.0741 - val_accuracy: 0.9803
# Epoch 6/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.1030 - accuracy: 0.9691 - val_loss: 0.0689 - val_accuracy: 0.9813
# Epoch 7/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.0963 - accuracy: 0.9708 - val_loss: 0.0631 - val_accuracy: 0.9825
# Epoch 8/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.0877 - accuracy: 0.9736 - val_loss: 0.0616 - val_accuracy: 0.9835
# Epoch 9/15
# 422/422 [==============================] - 9s 20ms/step - loss: 0.0816 - accuracy: 0.9746 - val_loss: 0.0568 - val_accuracy: 0.9843
# Epoch 10/15
# 422/422 [==============================] - 9s 20ms/step - loss: 0.0792 - accuracy: 0.9759 - val_loss: 0.0564 - val_accuracy: 0.9858
# Epoch 11/15
# 422/422 [==============================] - 9s 20ms/step - loss: 0.0749 - accuracy: 0.9767 - val_loss: 0.0545 - val_accuracy: 0.9847
# Epoch 12/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.0706 - accuracy: 0.9780 - val_loss: 0.0544 - val_accuracy: 0.9853
# Epoch 13/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.0680 - accuracy: 0.9794 - val_loss: 0.0543 - val_accuracy: 0.9857
# Epoch 14/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.0651 - accuracy: 0.9802 - val_loss: 0.0526 - val_accuracy: 0.9858
# Epoch 15/15
# 422/422 [==============================] - 9s 21ms/step - loss: 0.0631 - accuracy: 0.9797 - val_loss: 0.0512 - val_accuracy: 0.9855
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0506 - accuracy: 0.9840
# Test loss: 0.05055689811706543
# Test accuracy: 0.984000027179718
